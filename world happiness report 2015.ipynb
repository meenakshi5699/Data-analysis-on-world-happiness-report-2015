# %% [markdown]
#  ##                                   EDA  (Exploratory Data Analysis)

# %% [markdown]
# # `DATA ANALYSIS ON WORLD HAPPINESS REPORT 2015`

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## INTRODUCTION TO WORLD HAPPINESS REPORT

# %% [markdown]
# ##### The World Happiness Report is a publication that contains articles and rankings of national happiness, based on respondent ratings of their own lives, which the report also correlates with various (quality of) life factors. As of March 2023, Finland has been ranked the happiest country in the world six times in a row.
# ##### The report is a publication of the Sustainable Development Solutions Network, a global initiative of the United Nations. The report primarily uses data from the Gallup World Poll. Each annual report is available to the public to download on the World Happiness Report website. The editors of the 2023 report are John F. Helliwell, Richard Layard, Jeffrey D. Sachs, Jan-Emmanuel De Neve, Lara Aknin, and Shun Wang.
#
# ### Methods and philosophy
# ##### The rankings of national happiness are based on a Cantril ladder survey undertaken world-wide by the polling company Gallup, Inc. Nationally representative samples of respondents are asked to think of a ladder, with the best possible life for them being a 10, and the worst possible life being a 0. They are then asked to rate their own current lives on that 0 to 10 scale. The report correlates the life evaluation results with various life factors.

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# # Link of dataset : [world happiness report 2015](https://www.kaggle.com/datasets/unsdsn/world-happiness)

# %% [markdown]
# # <span style="color:Gold">**TABLE OF CONTENTS**</span>

# %% [markdown]
# ###  <span style="color:Red">1.Objective</span>
# ###  <span style="color:Red">2.Features of dataset</span>
# ### <span style="color:Red">3.Library Used</span>
# ###  <span style="color:Red">4.Data Description</span>
# ###  <span style="color:Red">5.Missing Values</span>
# ###  <span style="color:Red">6.Bargraph</span>
# ###  <span style="color:Red">7.Scatterplot</span>
# ###  <span style="color:Red">8.Boxplot</span>
# ###  <span style="color:Red">9.Lineplot</span>
# ###  <span style="color:Red">10.Heatmap</span>
# ###  <span style="color:Red">11.Pie-chart</span>
# ###  <span style="color:Red">12.Conclusion</span>

# %% [markdown]
# ## 1. Objective  :-
#  * >**To determine the relation between Happiness score and health**
#  * >**To determine the relation between Happiness score and economy.**
#   * >**To compare the happiness score of different regions.**

# %% [markdown]
# ## 2. Features of dataset
#
# * **Happiness Rank** - Rank of the country based on the Happiness Score.
# * **Happiness Score** - A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a score of 10
# * **Standard Error** -The standard error of the happiness score.
# * **Economy (GDP per Capita)** -The extent to which GDP contributes to the calculation of the Happiness Score.
# * **Family** - The extent to which Family contributes to the calculation of the Happiness Score
# * **Health (Life Expectancy)** -The extent to which Life expectancy contributed to the calculation of the Happiness Score
# * **Freedom** -The extent to which Freedom contributed to the calculation of the Happiness Score.
# * **Trust (Government Corruption)** - The extent to which Perception of Corruption contributes to Happiness Score.
# * **Generosity** -  residual of regressing national average of response to the generosity question
# * **Dystopia Residual** -  Score of Dystopia(hypothetical country consisting of the least happy people) + Residual for the corresponding country.

# %% [markdown]
#    ## 3. Library Used

# %%
import pandas as pd  #to manipulate the data
import numpy as np  # for scientific and mathematical calculation
import matplotlib.pyplot as plt # To design the graphs and charts
# %matplotlib inline 
import seaborn as sns #To make statistical graphs and charts
import plotly.express as px

# %% [markdown]
# ## 4.Data Description

# %%
#First read the data file
df = pd.read_csv('2015.csv')

# %% [markdown]
# ## Screenshot of our dataset:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Basic information on dataset:
# * It consists of 12 columns and 158 rows.
# * This dataset represents the world happiness report of year 2015.
# * Here, **Switzerland** has scored highest and **Togo** has scored lowest according to the report.

# %%
#quick look to our datafile
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
#the complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe() #Center theorem
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# ## 5. Missing Values

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
# Out:
# 0

# %% [markdown]
# **Since we don't have any missiing values in the dataset so we can now go for EDA cycle.**

# %% [markdown]
# -----------------------------------------------------------------
# -----------------------------------------------------------------

# %% [markdown]
# ## 6. Bargraph

# %%
plt.figure(figsize=(15, 25))
ax = sns.barplot(x='Happiness Score', y='Region',  data=df)
ax.spines[['top', 'right']].set_visible(False)
sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       2 ax = sns.barplot(x='Happiness Score', y='Region',  data=df)
#       3 ax.spines[['top', 'right']].set_visible(False)
# ----> 4 sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:453, in move_legend(obj, loc, **kwargs)
#     451 if old_legend is None:
#     452     err = f"{obj} has no legend attached."
# --> 453     raise ValueError(err)
#     455 # Extract the components of the legend we need to reuse
#     456 handles = old_legend.legendHandles
#
# ValueError: AxesSubplot(0.125,0.11;0.775x0.77) has no legend attached.

# %%
# the following code matches the plot produced by catplot
plt.figure(figsize=(15, 25))
ax = sns.barplot(x='Health (Life Expectancy)', y='Region',  data=df)
ax.spines[['top', 'right']].set_visible(False)
sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       3 ax = sns.barplot(x='Health (Life Expectancy)', y='Region',  data=df)
#       4 ax.spines[['top', 'right']].set_visible(False)
# ----> 5 sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:453, in move_legend(obj, loc, **kwargs)
#     451 if old_legend is None:
#     452     err = f"{obj} has no legend attached."
# --> 453     raise ValueError(err)
#     455 # Extract the components of the legend we need to reuse
#     456 handles = old_legend.legendHandles
#
# ValueError: AxesSubplot(0.125,0.11;0.775x0.77) has no legend attached.

# %% [markdown]
# * The above image shows the bargraph, comparing the health(life expectency) of different regions.
# * It was found to be max in 'Australia and New Zealand'.
# * It was found to be  min in Sub-Saharan Africa.

# %%
plt.figure(figsize=(25, 25))
ax = sns.barplot(x='Economy (GDP per Capita)', y='Region',  data=df)
ax.spines[['top', 'right']].set_visible(False)
sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 ax = sns.barplot(x='Economy (GDP per Capita)', y='Region',  data=df)
#       3 ax.spines[['top', 'right']].set_visible(False)
# ----> 4 sns.move_legend(ax, bbox_to_anchor=(2, 1.5), loc='center left', frameon=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:453, in move_legend(obj, loc, **kwargs)
#     451 if old_legend is None:
#     452     err = f"{obj} has no legend attached."
# --> 453     raise ValueError(err)
#     455 # Extract the components of the legend we need to reuse
#     456 handles = old_legend.legendHandles
#
# ValueError: AxesSubplot(0.125,0.11;0.775x0.77) has no legend attached.

# %% [markdown]
# * The above image shows the bargraph, comparing the economy(GDP per Capita) of different regions.
# * It was found to be max in 'North  America'.
# * It was found to be  min in 'Sub-Saharan Africa'.

# %% [markdown]
# ## 7.Scatterplot

# %%
# plotly scatterplot
fig = px.scatter(df, x="Happiness Score", y="Health (Life Expectancy)", color="Region", hover_name="Country", log_x=True, size_max=80)
fig.show()
# Out:
# <div>                            <div id="b2689138-9474-4e7b-ac7d-a91e01e758c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2689138-9474-4e7b-ac7d-a91e01e758c6")) {                    Plotly.newPlot(                        "b2689138-9474-4e7b-ac7d-a91e01e758c6",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Region=Western Europe<br>Happiness Score=%{x}<br>Health (Life Expectancy)=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Spain","Malta","Italy","North Cyprus","Cyprus","Portugal","Greece"],"legendgroup":"Western Europe","marker":{"color":"#636efa","symbol":"circle"},"mode":"mark
# ...

# %% [markdown]
# * The above diagram is the scatterplot of Happiness score vs Health(Life Expectency).
# * The happiness score is found to increasing with increase in health(life expectency).

# %%
fig = px.scatter(df, x="Happiness Score", y="Economy (GDP per Capita)", color="Region", hover_name="Country", log_x=True, size_max=80)
fig.show()
# Out:
# <div>                            <div id="7acfc5e0-156a-4f39-8ca0-bab0e817142a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7acfc5e0-156a-4f39-8ca0-bab0e817142a")) {                    Plotly.newPlot(                        "7acfc5e0-156a-4f39-8ca0-bab0e817142a",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Region=Western Europe<br>Happiness Score=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Spain","Malta","Italy","North Cyprus","Cyprus","Portugal","Greece"],"legendgroup":"Western Europe","marker":{"color":"#636efa","symbol":"circle"},"mode":"mark
# ...

# %% [markdown]
# The happiness score is found to increasing with increase in economy(GDP per Capita).

# %% [markdown]
# --------------------------

# %% [markdown]
# ## 8.Boxplot

# %%
sns.boxplot(
    data=df,  y="Health (Life Expectancy)"
    ,
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.3, .5, .7, .5)},
    medianprops={"color": "r", "linewidth": 2},
)
# Out:
# <AxesSubplot: ylabel='Health (Life Expectancy)'>

# %% [markdown]
# * The max score of health is 0.8 and min score is 0.4.
# * It is left skewwed. {Skewness Comparision}
# * The median of the data is 0.7.

# %%
sns.boxplot(
    data=df,  y="Economy (GDP per Capita)"
    ,
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.3, .5, .7, .5)},
    medianprops={"color": "r", "linewidth": 2},
)
# Out:
# <AxesSubplot: ylabel='Economy (GDP per Capita)'>

# %% [markdown]
# * The max score of health is 1.2 and min score is 0.6.
# * It is left skewwed. {Skewness Comparision}
# * The median of the data is 0.9.

# %% [markdown]
# ## 9.Lineplot

# %%
# seaborn lineplot
sns.lineplot(data=df,  x="Happiness Score", y="Health (Life Expectancy)")
# Out:
# <AxesSubplot: xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %% [markdown]
# * The above diagram shows the lineplot of Happiness score vs Health(life expectency).
# * It is unsymmetrical. {skewness}
# * The above data is multi modal.

# %%
# seaborn lineplot
sns.lineplot(data=df, x="Happiness Score", y="Economy (GDP per Capita)")
# Out:
# <AxesSubplot: xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %% [markdown]
# * The above diagram shows the lineplot of Happiness score vs economy.
# * It is unsymmetrical. {skewness}
# * The above data is multi modal.

# %% [markdown]
# ## 10.Heatmap

# %%
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features', size = 15)
colormap = sns.diverging_palette(10, 220, as_cmap = True)
sns.heatmap(df.corr(),
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':12 })
plt.show()
# Out:
# C:\Users\Meenakshi\AppData\Local\Temp\ipykernel_22372\4218888453.py:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ##### In above correlation matrix, we printed the number also so it will be easy for us to see which are highly corelated Value close to 1.00 is highly corelated.
#
# ### As per our objective,we see that " Happiness score" and "Health life expectency" have value 0.72 which is above 0.0 and we can say that they are  very correlated(positively).

# %% [markdown]
# -----------------------------------------

# %% [markdown]
# ##### In above correlation matrix, we printed the number also so it will be easy for us to see which are highly corelated Value close to 1.00 is highly corelated.
#
# ### As per our objective,we see that "Happiness score" and "Economy" have value 0.78 which is above 0.0 and we can say that they are  very correlated (positively).

# %% [markdown]
# -----------------------------------------------------
# -------------------------------

# %% [markdown]
# ## 11.Pie-chart

# %%
fig = px.pie(df,names='Region',title='Proportion Of Different Regions in Our Dataset',hover_data=['Region'])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="a82019ed-16c6-4022-bbdd-d1eaf70b7a44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a82019ed-16c6-4022-bbdd-d1eaf70b7a44")) {                    Plotly.newPlot(                        "a82019ed-16c6-4022-bbdd-d1eaf70b7a44",                        [{"customdata":[["Western Europe"],["Western Europe"],["Western Europe"],["Western Europe"],["North America"],["Western Europe"],["Western Europe"],["Western Europe"],["Australia and New Zealand"],["Australia and New Zealand"],["Middle East and Northern Africa"],["Latin America and Caribbean"],["Western Europe"],["Latin America and Caribbean"],["North America"],["Latin America and Caribbean"],["Western Europe"],["Western Europe"],["Western Europe"],["Middle East a
# ...

# %% [markdown]
# # 12.Conclusion

# %% [markdown]
# #### The nation with proper economy and health status are found to be more happier. As, a result both economy and health go side by side with happiness score.
# #### North America has better happiness score compared to other regions and Sub-Saharan seems to have worst.

# %% [markdown]
# -----

# %% [markdown]
# # Since objective is set, EDA cycle has been completed. ( •̀ ω •́ )✧
